# %% [markdown]
# # <center> IIIT Vadodara </center>
# ## <center> Winter 2022-23 </center>
# ## <center> CS/IT 308 Machine Learning Lab </center>
# ## <center> Lab#3 Principal component analysis (PCA) and Data generating process </center>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import misc
from numpy import linalg as la
import matplotlib.image as mpimg
import glob
from numpy import linalg as LA
import scipy.io as sio 
from mpl_toolkits import mplot3d

# %% [markdown]
# ## <font color='red'> 1. Implement PCA for 2D Data.
#
# In this experiment consider 200 samples and obtain the matrix $X$ in $X = C \times D$, where $C=\begin{bmatrix}
# 1 & 2 \\
# 1 & 1 \end{bmatrix}$ and $D$ is the randomly generated matix using samples. <font>
#
#
# Hint for Code: Use np.linalg.eig, np.diag, np.matmul, np.cov

# %%
# 2D Data for example
# Find X
D = np.random.rand(2,200)
C = np.array([[1,2],[1,1]])
X = np.dot(C,D)
print(X)
# Out:
# [[0.72043769 0.76887151 2.01909745 1.55947894 1.11322015 1.43092999
#   1.23561691 1.0626287  1.35836974 0.91920321 1.47647399 2.75154395
#   1.94181785 1.96791271 0.68687022 1.96971772 1.59768815 2.31103602
#   1.65323241 1.93697409 2.12169247 1.22421532 1.01439752 2.00326435
#   0.43652168 2.01077944 1.32876788 1.50582996 1.88311122 0.87609343
#   1.12013482 0.55017771 0.37004055 1.98724538 0.80924117 0.71483175
#   2.10495105 0.63932081 1.16921074 2.61878493 1.04752438 2.52725736
#   2.229141   2.69608388 2.14251927 0.88100807 1.16277247 1.19004427
#   2.44878392 0.6561079  1.50521068 2.19928844 1.9405115  1.32585595
#   1.99743618 0.92632964 2.43098856 0.66195182 1.06216881 2.0645291
#   0.80672233 1.7179212  1.0172111  0.42750038 1.37519852 1.95712943
#   1.89312084 1.47410056 2.0996732  0.89751762 0.45178646 1.54724875
#   2.61606442 1.52617138 2.22382249 1.21772628 0.21020806 1.26270248
#   0.75293092 1.92386846 0.91454148 1.08569184 1.55627521 1.82678991
#   1.61458726 2.74448434 2.26020666 1.44102691 1.29988576 2.39160465
#   2.24819708 2.05013446 0.77014787 2.20106032 0.86382664 1.29416775
#   2.02855391 1.37738168 1.53343022 1.90355894 0.46438513 0.4013416
#   1.81391072 1.28753595 1.63605931 1.39773002 1.43763024 1.53785964
#   1.75172262 1.67549146 0.65070363 2.26311907 1.74797478 1.82714784
#   2.14953664 0.81799752 1.93809531 1.44014818 2.56300828 2.51555242
#   2.3406823  2.30757218 1.4817949  1.2999708  2.26220047 0.93107587
#   1.65439429 1.78641181 1.55230557 0.70804107 1.94995041 2.36037233
#   2.28964562 2.88852542 1.93085467 2.44238619 2.47243632 0.89721712
#   1.5024625  1.64304956 2.62135524 1.27637424 0.70857305 2.09309677
#   1.74962465 1.54343758 1.03967873 0.93321724 1.32850688 1.50044446
#   2.44467843 1.72189788 0.18114138 1.05691964 1.60143789 0.5501052
#   2.41130384 1.89279339 1.42838673 1.94619631 2.81061419 2.56546791
#   2.03367863 2.64652045 1.29043325 2.05101903 1.12253224 0.66015113
#   1.96854821 0.44203673 2.09769324 1.17829165 1.97902153 1.91456313
#   0.71318199 1.76287459 1.38459563 1.81749984 0.19413014 0.93123617
#   0.42109426 1.24490809 2.07090747 1.24187505 1.57322079 0.99795796
#   1.45557276 1.26416715 1.67408346 2.09734531 0.79180562 2.50326246
#   1.76490681 1.56321202 0.77992846 1.29825617 1.04055256 0.63337343
#   2.16684721 0.79372817]
#  [0.68208899 0.42267337 1.14529562 0.93383108 0.90925974 0.87693944
#   0.63445804 0.64140813 0.71659884 0.85790633 0.77273484 1.80101112
#   1.17007566 1.17948968 0.50392808 1.3976519  1.17324702 1.62122534
#   0.95700296 1.31091386 1.50232397 0.93929917 0.92774454 1.46166214
#   0.21871192 1.47730533 0.9009039  1.11115352 0.98052612 0.64721053
#   0.63011517 0.31873738 0.35466835 1.27813797 0.7448911  0.60952092
#   1.35138603 0.36817457 0.95275343 1.7963248  1.00883133 1.60894962
#   1.47352392 1.8315976  1.19416499 0.44815014 1.0150941  0.96629648
#   1.53341864 0.51427034 1.21113532 1.5910012  1.25707478 0.71560912
#   1.3648702  0.50195873 1.62105347 0.42130004 0.90968326 1.12180258
#   0.53112828 1.16144711 0.59303417 0.35085282 0.93169371 1.16745142
#   1.2427929  0.96425775 1.53740537 0.89266114 0.39981192 0.82200066
#   1.80629699 0.79209947 1.55955932 0.8395293  0.19052504 0.89424911
#   0.39800967 1.17800131 0.74186883 0.5714514  0.78626571 0.93237969
#   1.12888247 1.86942704 1.51856431 0.91808718 1.05996448 1.60239495
#   1.48615518 1.09757254 0.52516505 1.29678086 0.47804962 0.66726875
#   1.44899111 0.76259192 1.03518182 1.24320051 0.26261693 0.32936344
#   1.22957929 0.87830264 1.08805852 0.76344916 1.07888011 1.23588634
#   0.99130709 1.01281815 0.5668167  1.29635208 1.02191941 1.28651819
#   1.30879443 0.58955806 1.26125798 1.0666134  1.7073775  1.64605858
#   1.5521523  1.4065221  1.00599775 0.83989202 1.32570413 0.85558145
#   1.07144574 1.07052687 0.94516167 0.64792601 1.07617922 1.5505703
#   1.56882248 1.88988936 1.05195005 1.65141293 1.71854754 0.57625828
#   1.08560178 1.13223431 1.63130459 0.89986548 0.65546558 1.14276158
#   1.15463891 1.14005792 0.67948892 0.46722124 1.1379546  1.04008259
#   1.44692803 0.99510611 0.10110179 0.70719514 1.26746774 0.40581732
#   1.62503359 1.19083716 1.03184594 1.05041452 1.87059918 1.77039696
#   1.21120215 1.74294986 0.69481495 1.41128703 1.05239602 0.51270236
#   1.11992233 0.35690486 1.20954421 1.07356287 1.26408672 1.39026695
#   0.52124428 1.12967459 0.80420266 1.03302259 0.09988772 0.83613486
#   0.28630894 0.85193523 1.07843376 0.91737741 1.212385   0.78591018
#   0.78072028 0.80386082 1.06987473 1.17941351 0.49712509 1.50909226
#   1.00124274 0.84004948 0.53580575 1.09853047 0.67006951 0.36961854
#   1.57088569 0.7342965 ]]

# %%
# code to scatter plot X
plt.scatter(x = X[0,:],y = X[1,:])

# %% [markdown]
# ### Implement PCA
# Hint: refer class note

# %%
# Write code to impement PCA

cov_mat = np.cov(X)
E_x,P = np.linalg.eig(cov_mat)
i = E_x.argsort()[::-1]
E = E_x[i]
P = P[:,i]

print('eigen values=',E)
print('eigen vectors=\n',P)
# Out:
# eigen values= [0.55292908 0.01240476]
# eigen vectors=
#  [[ 0.84805517 -0.52990794]
#  [ 0.52990794  0.84805517]]

# %%
# Transform data to new coordinates
P = P.T
Y = np.dot(P,X)

# scatter plot Y
plt.scatter(x = Y[0,:],y = Y[1,:])

# %%
#Approximate each 2-point data vector using one values
# Hint: Y[-1,:]=0
Y[-1,:] = 0

# scatter plot Y
plt.scatter(x = Y[0,:],y = Y[1,:])

# %%
#Transform back to original coordinates
PP = P.T
PP = PP[:,:-1]
YY = Y[:-1,:]
X_approx = PP * YY

# scatter plt X_approx
plt.scatter(x = X_approx[0,:],y = X_approx[1,:])

# %% [markdown]
# ## <font color='red'> 2. Implement PCA for 3D Data.
# In this experiment consider 200 samples and obtain the matrix $X$ in $X = C \times D$, where $$C=\begin{bmatrix}
# 1&2&-1\\
# 2&2&1\\
# -2&0&2\\
# \end{bmatrix}$$ and $D$ is the randomly generated matix using samples. <font>
#
# Hint for Code: Use np.linalg.eig, np.diag, np.matmul, np.cov

# %%
# Write 3D Data and find X
C = np.array([[1,2,-1],[2,2,1],[-2,0,2]])
D = np.random.rand(3,200)
X = np.dot(C,D)
print(X)
# Out:
# [[ 1.40040489e+00  2.11159296e+00  1.30690411e+00  2.57735898e+00
#    1.66419618e+00  8.99217902e-01  4.39263934e-01  1.63822932e+00
#    4.13930696e-01  9.68804304e-01 -6.63059922e-01  8.74030007e-01
#    9.59513743e-01  9.54624468e-01  3.10133599e-01  1.62808053e+00
#    8.46949595e-01  1.58847245e+00  1.01203973e+00  4.87503165e-01
#    2.05337511e+00 -6.39893525e-02  9.28280274e-01  2.01406255e-03
#    1.40421944e+00  1.06997103e+00 -5.04177373e-02  7.71019432e-01
#    1.72869441e+00  1.76879273e-01  2.57594188e+00  1.34513883e+00
#    2.09958795e+00  1.76947738e-01  1.26943683e+00  2.17716825e+00
#    1.14896469e+00  1.35585599e+00  3.00894777e-01  7.79212554e-01
#    1.58690726e+00  1.20915910e-01  6.12646628e-01  1.16230539e+00
#    3.21673791e-01  1.78846805e+00  1.14647620e+00  1.13751171e+00
#    1.97353003e+00  1.37107274e+00  8.99573844e-01  8.74173631e-01
#    1.41017650e+00  1.85358300e+00  1.49659998e+00  2.26849276e-01
#    1.43250017e+00  1.81800071e+00  3.00938663e-02  7.54358105e-01
#    1.61521626e+00  1.88392022e-01  8.67749823e-01  1.47592597e+00
#    9.10530154e-01  8.81718057e-01  1.48762333e+00  1.10521965e+00
#    1.39211240e+00  1.64555355e+00  1.47270940e+00  5.74766729e-01
#    3.59107302e-01  2.45633853e+00  2.17339203e+00 -7.65675459e-02
#    1.40203050e+00  6.19843780e-01  3.63988983e-01  9.01931519e-01
#    6.76922837e-01  1.79057276e+00  1.76396731e+00  8.96705516e-01
#    7.71652814e-01  2.84257415e-01  1.26067870e+00  1.16186843e+00
#    7.76207441e-01  5.33500591e-01  4.08060768e-01  1.00604352e+00
#    1.73424004e+00  2.15710126e+00  1.44410689e+00  1.50124604e+00
#    6.10139454e-01  3.98784562e-01 -2.49830210e-01  7.42461320e-01
#    4.11688376e-01  2.32742564e+00  1.95062094e+00  1.00517731e+00
#    9.42340995e-01 -1.58085591e-01  1.15715274e+00  1.85090997e+00
#    1.34661310e+00  1.62385739e+00  1.76832665e+00  1.15421863e+00
#    2.20061250e+00  2.00055627e+00  6.27014327e-01  2.11462922e+00
#    1.71855607e-01  5.40357238e-01  9.05275420e-01  4.94146711e-02
#    1.22389272e+00  1.72316627e+00  1.75365530e-01  1.84559430e+00
#    3.77390788e-01  1.02071987e+00  1.30030914e+00  6.52961466e-01
#    1.06235943e+00  1.77955241e+00  1.95821649e+00  1.64736137e+00
#   -3.02010589e-01  4.34635988e-01  7.61451302e-01  1.52694116e+00
#    1.24503529e+00 -4.94000126e-01  2.38326768e+00 -1.81451013e-01
#    2.16516333e-01  9.24629134e-01  4.60195965e-01 -3.64857488e-01
#    3.52234823e-01  8.18920652e-01  1.17521204e+00  1.00209057e+00
#    1.91748690e+00  1.21429827e+00  3.05442775e-01  1.42485481e+00
#    1.45312786e+00  1.12799505e+00  1.97139503e+00  1.17541852e+00
#   -2.15890519e-01  4.19727664e-01  5.08239029e-01  1.79059162e+00
#    1.99547682e+00  1.31080834e-01  1.52768505e+00  3.67181778e-01
#    1.18089710e+00  7.24743723e-01  1.10551503e+00 -2.31941325e-01
#   -4.77390367e-01  1.38879738e+00  1.01798657e+00  1.59222889e+00
#    7.11683705e-01  6.29375004e-01  1.97446125e+00  1.23775620e+00
#    1.82769340e+00  1.31002970e+00  1.53982247e+00  8.30681902e-01
#   -2.94113062e-01  7.94326599e-01  1.31252175e+00  2.43564985e-02
#    1.08499786e+00  1.28646417e+00  1.16584549e+00  1.70589606e+00
#    1.65913398e+00  2.40157706e+00 -4.03970881e-01 -4.02791112e-01
#    3.74104162e-01  1.42285920e+00  1.38623612e+00  8.53399121e-01
#    1.22173227e+00 -4.16681586e-01  1.84274713e-01  1.73696110e+00]
#  [ 2.72251391e+00  3.89043739e+00  3.25372839e+00  3.62666025e+00
#    3.41294570e+00  3.24991163e+00  1.28253088e+00  2.27074422e+00
#    3.20141775e+00  2.78647481e+00  1.31749006e+00  1.60410388e+00
#    2.46493855e+00  2.13705646e+00  1.05631802e+00  2.59047187e+00
#    2.49252461e+00  2.97266700e+00  2.07005825e+00  1.19509131e+00
#    3.17884663e+00  1.72032761e+00  3.16301966e+00  1.61777374e+00
#    1.69433629e+00  1.80548487e+00  2.36901138e+00  2.15815012e+00
#    3.35494329e+00  8.26372902e-01  3.96136166e+00  3.83017271e+00
#    3.85328504e+00  2.13359628e+00  3.23904989e+00  3.63442583e+00
#    3.73772615e+00  3.17035859e+00  2.00556430e+00  1.59684964e+00
#    2.81072718e+00  2.38291103e+00  2.59770521e+00  3.13945091e+00
#    2.00303393e+00  1.99393737e+00  2.14597580e+00  1.70453113e+00
#    3.77281584e+00  3.05800289e+00  1.82393087e+00  2.30638639e+00
#    1.86101512e+00  2.96963321e+00  3.14339222e+00  1.40306097e+00
#    3.37447173e+00  1.94368673e+00  1.77289758e+00  2.08187780e+00
#    2.90113040e+00  1.13186344e+00  1.33352712e+00  2.46006138e+00
#    3.58423392e+00  1.36549699e+00  1.72644150e+00  3.53079632e+00
#    3.04814911e+00  4.05456150e+00  2.90713099e+00  2.85230679e+00
#    2.68967913e+00  4.12098810e+00  3.28681469e+00  1.87391768e+00
#    2.55166424e+00  1.59009010e+00  2.15321423e+00  3.03212760e+00
#    2.17943725e+00  2.60597481e+00  2.54790181e+00  1.74048854e+00
#    1.00929999e+00  1.40657295e+00  2.17197967e+00  2.80617509e+00
#    2.07467325e+00  1.83655835e+00  2.31317526e+00  2.61777633e+00
#    2.72671994e+00  3.09483399e+00  2.47029782e+00  3.93552757e+00
#    1.58559489e+00  1.68686412e+00  1.44496518e+00  2.27218407e+00
#    2.48441129e+00  3.45001490e+00  2.17252496e+00  2.97349687e+00
#    2.01150419e+00  2.54763699e+00  2.86352833e+00  3.28589296e+00
#    2.43678632e+00  2.32818942e+00  3.23562446e+00  3.71526144e+00
#    3.68407437e+00  3.31296334e+00  1.14011700e+00  3.18167831e+00
#    9.82011807e-01  1.55130948e+00  2.70330724e+00  1.96059787e+00
#    2.73097823e+00  3.22017739e+00  2.53595430e+00  2.60611735e+00
#    1.52348733e+00  2.04913325e+00  2.17227927e+00  3.17193810e+00
#    3.19577301e+00  4.60923941e+00  2.37140582e+00  2.57069939e+00
#    1.96393264e+00  3.08582148e+00  2.23888053e+00  2.22717921e+00
#    3.38136522e+00  1.74114513e+00  3.20977381e+00  2.25733920e+00
#    1.86937607e+00  2.54250925e+00  2.21456577e+00  9.04215955e-01
#    2.56625680e+00  2.98401596e+00  2.56392889e+00  2.36228636e+00
#    4.16058488e+00  2.64035631e+00  1.83237106e+00  3.39216297e+00
#    2.83519074e+00  1.77170545e+00  3.73428645e+00  2.88489570e+00
#    1.22934685e+00  2.19317878e+00  2.25543717e+00  2.27284574e+00
#    3.15605686e+00  2.11432479e+00  2.20155595e+00  2.74840783e+00
#    3.14001642e+00  2.48061455e+00  3.37760459e+00  1.25040225e+00
#    1.03156186e+00  3.08160325e+00  1.33903870e+00  2.74208493e+00
#    2.95187361e+00  1.94409931e+00  3.11838986e+00  1.89001966e+00
#    3.81069904e+00  3.59024681e+00  2.70991106e+00  2.72161872e+00
#    1.37489916e+00  1.74421649e+00  3.16032837e+00  1.56531589e+00
#    2.48343153e+00  3.65810443e+00  1.57706755e+00  2.56991226e+00
#    3.90304234e+00  3.58135359e+00  1.37360816e+00  1.35995676e+00
#    2.92395877e+00  3.86625592e+00  2.51150762e+00  2.63323303e+00
#    3.12146437e+00  2.06655014e+00  6.85123809e-01  2.17219347e+00]
#  [ 9.27742707e-01 -5.51536412e-01  3.60741380e-01 -1.91085970e+00
#   -2.47845303e-01  4.47977311e-01 -6.80799624e-01  3.87604037e-01
#    1.42176968e-01  3.28440109e-01  1.67781720e+00  1.06645551e-01
#    9.18449794e-01 -1.62104561e+00  4.27455834e-01 -8.52364087e-01
#    2.84222377e-01 -1.45815757e-01 -7.08945407e-01  2.94570097e-01
#   -6.76964203e-01  8.17725213e-01  5.43583972e-01  1.55421216e+00
#   -2.53126386e-01 -1.18165026e-01  8.70802615e-01 -4.35103037e-01
#   -1.19801845e+00  5.61274830e-01 -1.59933756e+00  3.32254319e-01
#   -3.07932933e-01  1.55573763e+00 -1.29345189e-01 -3.55069026e-01
#    3.06760035e-01 -8.04359706e-01  1.03537669e+00  3.45524874e-01
#   -8.53689337e-01 -2.02669773e-01 -1.00449905e-01  9.59603066e-01
#    1.41677008e+00 -2.87747655e-01  2.09087049e-01 -2.36764632e-01
#   -1.59182685e-01  7.37290156e-01 -5.22749590e-01 -1.19755721e+00
#   -7.01249278e-01 -9.06576226e-01 -9.45646955e-01  8.59713531e-01
#    3.82325404e-01 -2.46508668e-01  3.89362087e-01  5.86147829e-01
#   -6.42690442e-01 -3.25471463e-01 -3.97345117e-01 -1.45581325e+00
#    6.30616834e-01 -8.31137676e-01  4.47379682e-02  6.83313108e-02
#   -9.68620132e-01  2.96587963e-01 -1.10942585e+00 -2.77419259e-01
#    1.01914179e+00 -9.55802396e-01 -1.75617266e+00  6.10328112e-01
#   -8.57320938e-01 -9.24057114e-01  6.92962180e-01  1.25365198e+00
#    2.20357022e-01 -9.09371063e-02 -8.09255066e-01 -8.40033581e-01
#   -2.78269431e-01  3.02984908e-01  8.71100577e-02  5.37936594e-01
#    7.51183592e-01  5.30307791e-01  3.23857287e-01 -1.08376322e+00
#   -1.90328979e+00 -4.02585358e-01  3.38653259e-01  6.92831087e-01
#    7.73022200e-02 -2.29650980e-01  1.20472031e+00  1.76785058e-01
#   -6.34779532e-01 -8.66465648e-01  2.80688807e-02 -4.91385465e-02
#   -1.49603601e+00  5.47201891e-01  1.21792709e+00 -1.49306324e+00
#    7.50674871e-01 -1.15278337e+00  7.91663766e-02 -4.06027718e-01
#   -5.99521802e-01 -1.24453482e+00  1.71174693e-01 -3.85022679e-01
#   -2.55401460e-01  8.79850133e-01  1.53966240e+00  1.38817171e+00
#   -8.47280103e-01  2.27970189e-01  4.51202326e-01 -3.49994100e-01
#   -5.48379186e-01 -1.74925133e+00 -9.88756104e-01  9.17725369e-01
#    1.33632953e+00  2.07513975e-01 -6.81053968e-01  3.49325460e-01
#    1.20460060e+00  9.92090421e-02  1.07488209e+00 -1.36477380e+00
#    1.38028432e+00  1.42711724e+00 -1.16835186e+00  9.94112205e-01
#   -2.90183576e-01  9.16165475e-01  5.50632698e-01  7.72167105e-01
#    1.19219937e+00  1.25466807e+00 -2.79350478e-01 -4.03610199e-01
#   -5.57791689e-01 -1.43980729e+00  1.23591050e+00 -2.97207365e-01
#    1.17090176e-01 -5.25596263e-01 -3.84077982e-01 -6.63762671e-01
#    9.74878990e-01  1.30471194e+00  1.21812335e+00  2.58385773e-01
#   -1.42734887e+00  6.18003682e-01 -2.15809977e-01 -1.53061307e-01
#    8.49230697e-01 -1.06945420e+00  7.88160550e-01  1.29399419e+00
#    9.86691033e-01  4.77676244e-01 -3.95367280e-02 -3.40923176e-02
#    1.11039009e+00  2.60524020e-01 -1.84260350e+00 -4.23429751e-01
#   -6.31286596e-01 -5.22879330e-01 -1.38003748e+00  1.54930921e+00
#    1.61875213e+00  8.21277573e-01 -1.04432261e+00  8.65063234e-01
#    1.02689226e+00  7.41969738e-01 -3.94154134e-01 -9.94492938e-01
#    6.06914927e-01 -1.37372354e+00  1.46688920e+00  1.46314613e+00
#   -3.92818463e-01  7.44027391e-01 -9.12203834e-01  1.58264922e+00
#   -5.21137045e-01  9.48013710e-01  5.00150431e-01 -5.14457681e-01]]

# %%
# write code to scatter plot 3D
fig = plt.figure(figsize=(4,4))
ax = plt.axes(projection="3d")
ax.scatter3D(X[0,:],X[1,:],X[2,:],color="purple")

# %% [markdown]
# ### Implement PCA
# Hint: refer class note.

# %%
#Write code here
cov_mat = np.cov(X)
E_x,P = np.linalg.eig(cov_mat)
i = E_x.argsort()[::-1]
E = E_x[i]
P = P[:,i]

print('eigen values=',E)
print('eigen vectors=\n',P)
# Out:
# eigen values= [1.24884682 0.53625395 0.11878905]
# eigen vectors=
#  [[ 0.58055649  0.10600178  0.8072904 ]
#  [ 0.52859109  0.7050774  -0.47271273]
#  [-0.61931061  0.70116295  0.35330566]]

# %%
# Transform data to new coordinates
P = P.T
Y = np.dot(P,X)

#Scatter plt Y
fig = plt.figure(figsize=(4,4))
ax = plt.axes(projection="3d")
ax.scatter3D(Y[0,:],Y[1,:],Y[2,:],color="purple")

# %%
#Approximate each 3-point data vector using two values
Y[2,:]=0

#Scatter plot Y
fig = plt.figure(figsize=(4,4))
ax = plt.axes(projection="3d")
ax.scatter3D(Y[0,:],Y[1,:],Y[2,:],color="purple")

# %%
#Transform back to original coordinates
PP = P.T
PP = PP[:,:-1]
YY = Y[:-1,:]
X_approx = np.dot(PP,YY)

#Scatter plot X_approx
fig = plt.figure(figsize=(4,4))
ax = plt.axes(projection="3d")
ax.scatter3D(X_approx[0,:],X_approx[1,:],X_approx[2,:],color="purple")

# %% [markdown]
# ## <font color='red'> 3. Implement PCA for image compression.<font>
#     Methodology: A set of face images is used to generate a basis matrix using PCA. Essentially this basis matrix would the input data which are correlated observations from the real world. By preserving different number of eigenvectors, different degrees of compression can be achieved.

# %% [markdown]
# You can use this link for face images:
#
# https://drive.google.com/file/d/1XMtBihZypbE-zlg_DuAW63IF4vX4cn3d/view?usp=sharing

# %%
a = glob.glob('*.pgm') # to read all images
X1 = mpimg.imread(a[0])
plt.imshow(X1)
plt.colorbar()
[m,n]=np.shape(X1)
X = X1.flatten()
X = np.zeros(shape=(np.size(a),m*n))
for i,j in zip(a,range(np.size(a))):
    X[j,:]=  mpimg.imread(i).flatten()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#plot Eigen values of covariance matrix
cov = np.cov(X)
eig,vec = np.linalg.eig(cov)

plt.figure()
plt.plot(eig)

# %%
#write code for PCA and approximate each data vector using few significant eigen values 
vec_red = vec[:,:12]
Xlr = X.T@vec_red
Xlr = Xlr.T
X1r = np.reshape(Xlr[0,:],[m,n])
plt.imshow(X1r)
plt.colorbar()

# %% [markdown]
# ### <font color='red'> Homework: Implement PCA for remote sensing image.<font>
#     Methodology: A set of remotely sensed images (Cuprite hyperspectral data having 188 bands) is used to generate a basis matrix based on PCA, and this matrix would be used to uncorrelate the data which are correlated. By preserving different number of eigenvectors different degrees of compression can be achieved. Find the variance of the input and output in each case and note the observations.

# %% [markdown]
# You can use this link for Cuprite images:
#
# https://drive.google.com/file/d/1XMtBihZypbE-zlg_DuAW63IF4vX4cn3d/view?usp=sharing

# %%
X = sio.loadmat('cuprite.mat')
X= X['x']
X1 = np.reshape(X,[188,191,250])
plt.figure()
plt.imshow(X1[1,:,:].T)
plt.colorbar()

# %%
#plot Eigen values of covariance matrix
co = np.cov(X)
eig,vec = np.linalg.eig(co)
plt.figure()
plt.plot(eig)
A = vec.T

# %%
#write code for PCA and approximate each data vector using few significant eigen values 
x = X1[:,1,:]
y = np.dot(A,x)
A_new = A.T
pp = A_new[:,:25]
yy = y[:25,:]
Xlr = pp@yy
print(Xlr.shape)

plt.imshow(X1r)
plt.colorbar()
# Out:
# (188, 250)

# %% [markdown]
# ## <font color='red'> 4. Data generating process:
# In this experiment take two zero mean, unit variance, uncorrelated Gaussian random variables. Obtain the transformation matrix $A$ in $Y = A \times X$ such that $Y$ has a specified covariance matrix. (Take any valid covariance matrix in this case)<font>
# Hint: $$Y=AX$$ $$C_Y=AC_XA^T$$ Digonalize $$C_Y=U\Sigma U^{-1}$$ So, $$U\Sigma^{\frac{1}{2}}\Sigma^{\frac{1}{2}} U^{-1}=AC_XA^T$$ If, $X$ is uncorrelated then $C_X$ must be identity.
# <br>
# Hint for Code: Use np.linalg.eig, np.diag, np.matmul, np.cov

# %%
#  For example use this Cy
Cy = np.array([[4 , 2],
               [2 , 4]])
print(Cy)
# Out:
# [[4 2]
#  [2 4]]

# %%
no_samples = 1000

#Write code here


print("Cy_new=",Cynew)
# Out:
# Cx= [[ 1.00296919 -0.01174075]
#  [-0.01174075  0.98357411]]
# Cy= [[4 2]
#  [2 4]]
# Cy_new= [[4.03315283 2.02533346]
#  [2.02533346 3.95181052]]

# %% [markdown]
# ### <font color='red'> Homework: Consider providing more valid covariance matrices and generate correlated random data using the reverse PCA operation done in Problem-4. This is an instance of data generating process useful in machine learning algorithms.
